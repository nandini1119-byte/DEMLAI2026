# %% [markdown]
# <a href="https://colab.research.google.com/github/nandini1119-byte/DEMLAI2026/blob/main/6_lambda_map_filter_reduce_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Section 1: Lambda Expressions — 20 Questions

# %% [markdown]
# Question 1
# number = 8
# Write a lambda expression to calculate the square of number.

# %%
num=8
sq=lambda x:x**2
print(sq(num))
# Out:
# 64

# %% [markdown]
# Question 2
# number = 5
# Write a lambda expression to calculate the cube of number.

# %%
num=int(input())
import math
cube=lambda x:x**3
print(cube(num))
# Out:
# 27

# %% [markdown]
# Question 3
# a = 25
# b = 17
# Write a lambda expression to add a and b.

# %%
a=25
b=17
add=lambda x,y : x+y
print(add(a,b))
# Out:
# 42

# %% [markdown]
# Question 4
# a = 50
# b = 18
# Write a lambda expression to subtract b from a.

# %%
a = 50
b = 18
sub=lambda a,b:a-b
print(sub(a,b))
# Out:
# 32

# %% [markdown]
# Question 5
# a = 12
# b = 9
# Write a lambda expression to multiply a and b.

# %%
a = 12
b = 9
mul=lambda a,b:a*b
print(mul(a,b))
# Out:
# 108

# %% [markdown]
# Question 6
# a = 100
# b = 4
# Write a lambda expression to divide a by b.

# %%
a = 100
b = 4
div=lambda a,b:a/b
print(div(a,b))
# Out:
# 25.0

# %% [markdown]
# Question 7
# a = 72
# b = 91
# Write a lambda expression to return the larger number

# %%
a = 72
b = 91
larget=lambda a,b:a if a>b else b
print(larget(a,b))
# Out:
# 91

# %% [markdown]
# Question 8
# a = 46
# b = 28
# Write a lambda expression to return the smaller number.

# %%
a = 46
b = 28
smallest=lambda a,b:a if a<b else b
print(smallest(a,b))
# Out:
# 28

# %% [markdown]
# Question 9
# number = 34
# Write a lambda expression that returns True when the number is even and False otherwise.

# %%
a = 34
even=lambda a:'even' if a%2==0 else False
print(even(a))
# Out:
# odd

# %% [markdown]
# Question 10
# number = 27
# Write a lambda expression that returns True when the number is odd and False otherwise.

# %%
a = 27
even=lambda a:'odd' if a%2!=0 else False
print(even(a))
# Out:
# odd

# %% [markdown]
# Question 11
# length = 12
# width = 8
# Write a lambda expression to calculate the area of a rectangle.

# %%
length = 12
width = 8
area=lambda x,y:x*y
print(area(length,width))
# Out:
# 96

# %% [markdown]
# Question 12
# radius = 7
# Write a lambda expression to calculate the area of a circle using 3.14.

# %%
pi=3.14
radius = 7
carea=lambda pi,radius:pi*(radius**2)
print(carea(pi,radius))
# Out:
# 153.86

# %% [markdown]
# Question 13
# length = 15
# width = 10
# Write a lambda expression to calculate the perimeter of a rectangle.

# %%
length = 15
width = 10
rarea=lambda a,b:1/2*length*width
print(rarea(length,width))
# Out:
# 75.0

# %% [markdown]
# Question 14
# celsius = 35
# Write a lambda expression to convert Celsius into Fahrenheit.

# %%
celsius=100
ctof=lambda x:(9/5)*x+32
print(ctof(celsius))
# Out:
# 212.0

# %% [markdown]
# Question 15
# fahrenheit = 104
# Write a lambda expression to convert Fahrenheit into Celsius.

# %%
fahren=104
ftoc=lambda x:(x-32)*5/9
print(ftoc(fahren))
# Out:
# 40.0

# %% [markdown]
# Question 16
# word = "Python"
# Write a lambda expression to return the length of the string.

# %%
word='Python'
length=lambda x:len(x)
print(len(word))
# Out:
# 6

# %% [markdown]
# Question 17
# word = "Azure"
# Write a lambda expression to return the first character of the string.

# %%
word='Azure'
length=lambda x:len(x)
print(length(word))
# Out:
# 5

# %% [markdown]
# Question 18
# word = "Databricks"
# Write a lambda expression to return the last character of the string.

# %%
word = "Databricks"
lst=lambda x:x[-1]
print(lst(word))
# Out:
# s

# %% [markdown]
# Question 19
# number = -45
# Write a lambda expression to return the absolute value of the number without using abs().

# %%
number = -45
absolute = lambda x: x if x >= 0 else -x

print(absolute(number))
# Out:
# 45

# %% [markdown]
# Question 20
# marks = 72
# Write a lambda expression that returns:
#
# "Distinction" when marks are 75 or above
# "Pass" when marks are 40 to 74
# "Fail" when marks are below 40

# %%
marks = 72
grade = lambda x: "Distinction" if x >= 75 else "Pass" if x >= 40 else "Fail"
print(grade(marks))
# Out:
# Pass

# %% [markdown]
# Section 2: map() — 20 Questions

# %% [markdown]
# Question 1
# numbers = [1, 2, 3, 4, 5, 6]
# Using map() and a lambda expression, calculate the square of every number.

# %%
numbers = [1, 2, 3, 4, 5, 6]
sq=map(lambda x:x**2,numbers)
print(list(sq))
# Out:
# [1, 4, 9, 16, 25, 36]

# %% [markdown]
# Question 2
# numbers = [2, 3, 4, 5, 6]
# Using map() and a lambda expression, calculate the cube of every number.

# %%
numbers = [2, 3, 4, 5, 6]
sq=map(lambda x:x**3,numbers)
print(list(sq))
# Out:
# [8, 27, 64, 125, 216]

# %% [markdown]
# Question 3
# numbers = [10, 20, 30, 40, 50]
# Using map(), add 5 to every number.

# %%
numbers = [10, 20, 30, 40, 50]
sq=map(lambda x:x+5,numbers)
print(list(sq))
# Out:
# [15, 25, 35, 45, 55]

# %% [markdown]
# Question 4
# numbers = [15, 25, 35, 45, 55]
# Using map(), subtract 10 from every number.

# %%
numbers = [15, 25, 35, 45, 55]
sq=map(lambda x:x-10,numbers)
print(list(sq))
# Out:
# [5, 15, 25, 35, 45]

# %% [markdown]
# Question 5
# numbers = [1, 5, 10, 15, 20]
# Using map(), multiply every number by 100.

# %%
numbers = [1, 5, 10, 15, 20]
sq=map(lambda x:x*100,numbers)
print(list(sq))
# Out:
# [100, 500, 1000, 1500, 2000]

# %% [markdown]
# Question 6
# names = ["ravi", "anil", "meena", "kiran", "sneha"]
# Using map(), convert every name to uppercase.

# %%
names = ["ravi", "anil", "meena", "kiran", "sneha"]
uc=map(lambda x:x.upper(),names)
print(list(uc))
# Out:
# ['RAVI', 'ANIL', 'MEENA', 'KIRAN', 'SNEHA']

# %% [markdown]
# Question 7
# names = ["RAHUL", "DIVYA", "ARJUN", "AJAY"]
# Using map(), convert every name to lowercase.

# %%
names = ["RAHUL", "DIVYA", "ARJUN", "AJAY"]
lc=map(lambda x:x.lower(),names)
print(list(lc))
# Out:
# ['rahul', 'divya', 'arjun', 'ajay']

# %% [markdown]
# Question 8
# names = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"]
# Using map(), convert every name to title case.

# %%
names = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"]
lc=map(lambda x:x.title(),names)
print(list(lc))
# Out:
# ['Rahul Kumar', 'Anil Sharma', 'Meena Reddy', 'Divya Singh']

# %% [markdown]
# Question 9
# words = ["Python", "Azure", "Databricks", "Cloud", "AI"]
# Using map(), calculate the length of every word.

# %%
words = ["Python", "Azure", "Databricks", "Cloud", "AI"]
lc=map(lambda x:len(x),words)
print(list(lc))
# Out:
# [6, 5, 10, 5, 2]

# %% [markdown]
# Question 10
# words = ["Python", "Azure", "Docker", "Linux", "Spark"]
# Using map(), extract the first character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
lc=map(lambda x:x[0],words)
print(list(lc))
# Out:
# ['P', 'A', 'D', 'L', 'S']

# %% [markdown]
# Question 11
# words = ["Python", "Azure", "Docker", "Linux", "Spark"]
# Using map(), extract the last character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
lc=map(lambda x:x[-1],words)
print(list(lc))
# Out:
# ['n', 'e', 'r', 'x', 'k']

# %% [markdown]
# Question 12
# temperatures = [0, 10, 20, 30, 40]
# Using map(), convert every Celsius temperature into Fahrenheit.

# %%
temperatures = [0, 10, 20, 30, 40]
ctf=map(lambda x:(9/5)*x+32,temperatures)
print(list(ctf))
# Out:
# [32.0, 50.0, 68.0, 86.0, 104.0]

# %% [markdown]
# Question 13
# prices = [100, 250, 500, 1000, 2500]
# Using map(), calculate 18% GST for every price.

# %%
prices = [100, 250, 500, 1000, 2500]
gst=map(lambda x:x*0.18,prices)
print(list(gst))
# Out:
# [18.0, 45.0, 90.0, 180.0, 450.0]

# %% [markdown]
# Question 14
# prices = [100, 250, 500, 1000, 2500]
# Using map(), calculate the final price after adding 18% GST.

# %%
prices = [100, 250, 500, 1000, 2500]
gst=map(lambda x:(x*0.18)+x,prices)
print(list(gst))
# Out:
# [118.0, 295.0, 590.0, 1180.0, 2950.0]

# %% [markdown]
# Question 15
# decimal_numbers = [12.4567, 45.8976, 78.1234, 99.9999]
# Using map(), round every number to two decimal places.

# %%
import math
decimal_numbers = [12.4567, 45.8976, 78.1234, 99.9999]
rou=map(lambda x:round(x,2),decimal_numbers)
print(list(rou))
# Out:
# [12.46, 45.9, 78.12, 100.0]

# %% [markdown]
# Question 16
# values = [-10, 20, -35, 40, -55, 60]
# Using map(), convert every number into its absolute value.

# %%
values = [-10, 20, -35, 40, -55, 60]
rou=map(lambda x:abs(x),values)
print(list(rou))
# Out:
# [10, 20, 35, 40, 55, 60]

# %% [markdown]
# Question 17
# numbers = [10, 20, 30, 40, 50]
# Using map(), convert every integer into a string.

# %%
numbers = [10, 20, 30, 40, 50]
its=map(lambda x: str(x), numbers)
print(list(its))
# Out:
# ['10', '20', '30', '40', '50']

# %% [markdown]
# Question 18
# names = ["  Ravi  ", " Anil", "Meena ", "  Kiran "]
# Using map(), remove leading and trailing spaces from every name.

# %%
names = ["  Ravi  ", " Anil", "Meena ", "  Kiran "]
strr=map(lambda x:x.strip(),names)
print(list(strr))
# Out:
# ['Ravi', 'Anil', 'Meena', 'Kiran']

# %% [markdown]
# Question 19
# employees = [
#     {"id": 101, "name": "Rahul", "salary": 45000},
#     {"id": 102, "name": "Anil", "salary": 65000},
#     {"id": 103, "name": "Sneha", "salary": 72000},
#     {"id": 104, "name": "Kiran", "salary": 82000}
# ]
# Using map(), extract only employee names.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
names=map(lambda x:x['name'],employees)
print(list(names))
# Out:
# ['Rahul', 'Anil', 'Sneha', 'Kiran']

# %% [markdown]
# Question 20
# employees = [
#     {"id": 101, "name": "Rahul", "salary": 45000},
#     {"id": 102, "name": "Anil", "salary": 65000},
#     {"id": 103, "name": "Sneha", "salary": 72000},
#     {"id": 104, "name": "Kiran", "salary": 82000}
# ]
# Using map(), create a new list of dictionaries containing:
#
# Employee name
# Original salary
# Salary after a 10% increment
# Do not modify the original list.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
newemployes=list(map(lambda emp:{"name": emp["name"],"original_salary": emp["salary"],
                "incremented_salary": emp["salary"] * 1.10},employees))
print(newemployes)
# Out:
# [{'name': 'Rahul', 'original_salary': 45000, 'incremented_salary': 49500.00000000001}, {'name': 'Anil', 'original_salary': 65000, 'incremented_salary': 71500.0}, {'name': 'Sneha', 'original_salary': 72000, 'incremented_salary': 79200.0}, {'name': 'Kiran', 'original_salary': 82000, 'incremented_salary': 90200.00000000001}]

# %% [markdown]
# Section 3: filter() — 20 Questions

# %% [markdown]
# Question 1
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# Using filter(), extract all even numbers.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
even=list(filter(lambda x:x%2==0,numbers))
print(even)
# Out:
# [12, 56, 34, 78, 100]

# %% [markdown]
# Question 2
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# Using filter(), extract all odd numbers.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
odd=list(filter(lambda x:x%2 !=0,numbers))
print(odd)
# Out:
# [45, 67, 89, 23, 91]

# %% [markdown]
# Question 3
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# Using filter(), extract all numbers greater than 50.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
gre=list(filter(lambda x:x>50,numbers))
print(gre)
# Out:
# [67, 89, 56, 91, 78, 100]

# %% [markdown]
# Question 4
# numbers = [120, 45, 167, 89, 230, 56, 91, 34, 178, 100]
# Using filter(), extract all numbers less than 100.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
small=list(filter(lambda x:x<100,numbers))
print(small)
# Out:
# [12, 45, 67, 89, 23, 56, 91, 34, 78]

# %% [markdown]
# Question 5
# numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
# Using filter(), extract all positive numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
positive=list(filter(lambda x:x>0,numbers))
print(positive)
# Out:
# [4, 12, 37, 42]

# %% [markdown]
# Question 6
# numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
# Using filter(), extract all negative numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
negitive=list(filter(lambda x:x<0,numbers))
print(negitive)
# Out:
# [-15, -8, -25]

# %% [markdown]
# Question 7
# numbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0]
# Using filter(), remove all zero values.

# %%
numbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0]
zero=list(filter(lambda x:x!=0,numbers))
print(zero)
# Out:
# [-15, -8, 4, 12, -25, 37]

# %% [markdown]
# Question 8
# words = ["python", "azure", "ai", "developer", "cloud", "analytics"]
# Using filter(), extract words containing more than five characters.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics"]
print(list(filter(lambda x:len(x)>5,words)))
# Out:
# ['python', 'developer', 'analytics']

# %% [markdown]
# Question 9
# names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
# Using filter(), extract names beginning with "A".

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
print(list(filter(lambda x:x.startswith('A'),names)))
# Out:
# ['Anil', 'Ajay', 'Arjun', 'Akhil']

# %% [markdown]
# Question 10
# names = ["Kiran", "Mohan", "Arjun", "Rajan", "Meena", "Varun"]
# Using filter(), extract names ending with "n".

# %%
names = ["Kiran", "Mohan", "Arjun", "Rajan", "Meena", "Varun"]
print(list(filter(lambda x:x.endswith('n'),names)))
# Out:
# ['Kiran', 'Mohan', 'Arjun', 'Rajan', 'Varun']

# %% [markdown]
# Question 11
# numbers = [10, 15, 18, 20, 25, 30, 32, 40, 45, 50]
# Using filter(), extract all multiples of 5.

# %%
numbers = [10, 15, 18, 20, 25, 30, 32, 40, 45, 50]
print(list(filter(lambda x:x%5==0,numbers)))
# Out:
# [10, 15, 20, 25, 30, 40, 45, 50]

# %% [markdown]
# Question 12
# numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
# Using filter(), extract numbers divisible by both 3 and 5.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
print(list(filter(lambda x:x%5==0 and x%3==0,numbers)))
# Out:
# [15, 30, 45, 60, 75]

# %% [markdown]
# Question 13
# words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
# Using filter(), extract all palindrome words.

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
print(list(filter(lambda x:x[::-1]==x,words)))
# Out:
# ['madam', 'level', 'radar', 'civic']

# %% [markdown]
# Question 14
# emails = [
#     "john@gmail.com",
#     "rahul@yahoo.com",
#     "admin@python.com",
#     "support@azure.org",
#     "sales@company.com"
# ]
# Using filter(), extract email addresses ending with ".com".

# %%
emails = [
    "john@gmail.com",
    "rahul@yahoo.com",
    "admin@python.com",
    "support@azure.org",
    "sales@company.com"
]
print(list(filter(lambda x:x.endswith('.com'),emails)))
# Out:
# ['john@gmail.com', 'rahul@yahoo.com', 'admin@python.com', 'sales@company.com']

# %% [markdown]
# Question 15
# files = [
#     "sales.csv",
#     "employees.xlsx",
#     "products.csv",
#     "report.pdf",
#     "customers.csv",
#     "notes.txt"
# ]
# Using filter(), extract all CSV files.

# %%
files = [
    "sales.csv",
    "employees.xlsx",
    "products.csv",
    "report.pdf",
    "customers.csv",
    "notes.txt"
]
print(list(filter(lambda x:x.endswith('.csv'),files)))
# Out:
# ['sales.csv', 'products.csv', 'customers.csv']

# %% [markdown]
# Question 16
# employees = [
#     {"name": "Rahul", "salary": 45000},
#     {"name": "Anil", "salary": 65000},
#     {"name": "Sneha", "salary": 72000},
#     {"name": "Kiran", "salary": 82000},
#     {"name": "Meena", "salary": 55000}
# ]
# Using filter(), extract employees whose salary is greater than 60000.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
print(list(filter(lambda x:x['salary']>60000,employees)))## to print all data
print(list(map(lambda x:x['name'],filter(lambda x:x['salary']>60000,employees))))## to print only names
# Out:
# [{'name': 'Anil', 'salary': 65000}, {'name': 'Sneha', 'salary': 72000}, {'name': 'Kiran', 'salary': 82000}]
# ['Anil', 'Sneha', 'Kiran']

# %% [markdown]
# Question 17
# students = [
#     {"name": "Ravi", "marks": 92},
#     {"name": "Kiran", "marks": 68},
#     {"name": "Meena", "marks": 85},
#     {"name": "Ajay", "marks": 48},
#     {"name": "Sneha", "marks": 79}
# ]
# Using filter(), extract students who scored more than 80.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79}
]
print(list(filter(lambda x:x['marks']>80,students)))
# Out:
# [{'name': 'Ravi', 'marks': 92}, {'name': 'Meena', 'marks': 85}]

# %% [markdown]
# Question 18
# products = [
#     {"name": "Laptop", "price": 55000, "stock": 5},
#     {"name": "Mouse", "price": 600, "stock": 25},
#     {"name": "Keyboard", "price": 1500, "stock": 0},
#     {"name": "Monitor", "price": 18000, "stock": 8},
#     {"name": "Printer", "price": 12000, "stock": 0}
# ]
# Using filter(), extract products that are currently in stock.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0}
]
print(list(filter(lambda x:x['stock']>0,products)))
print(list(map(lambda x :x['name'],filter(lambda x:x['stock']>0,products))))
# Out:
# [{'name': 'Laptop', 'price': 55000, 'stock': 5}, {'name': 'Mouse', 'price': 600, 'stock': 25}, {'name': 'Monitor', 'price': 18000, 'stock': 8}]
# ['Laptop', 'Mouse', 'Monitor']

# %% [markdown]
# Question 19
# people = [
#     {"name": "Rahul", "age": 17},
#     {"name": "Anil", "age": 25},
#     {"name": "Sneha", "age": 16},
#     {"name": "Kiran", "age": 32},
#     {"name": "Meena", "age": 18}
# ]
# Using filter(), extract people who are eligible to vote.

# %%
people = [
    {"name": "Rahul", "age": 17},
    {"name": "Anil", "age": 25},
    {"name": "Sneha", "age": 16},
    {"name": "Kiran", "age": 32},
    {"name": "Meena", "age": 18}
]
print(list(map(lambda x : x['name'],filter(lambda x:x['age']>18,people))))
# Out:
# ['Anil', 'Kiran']

# %% [markdown]
# Question 20
# employees = [
#     {"name": "Rahul", "department": "IT", "active": True},
#     {"name": "Anil", "department": "HR", "active": True},
#     {"name": "Sneha", "department": "IT", "active": False},
#     {"name": "Kiran", "department": "IT", "active": True},
#     {"name": "Meena", "department": "Sales", "active": True}
# ]
# Using filter(), extract employees who belong to the IT department and are active.

# %%
employees = [
    {"name": "Rahul", "department": "IT", "active": True},
    {"name": "Anil", "department": "HR", "active": True},
    {"name": "Sneha", "department": "IT", "active": False},
    {"name": "Kiran", "department": "IT", "active": True},
    {"name": "Meena", "department": "Sales", "active": True}
]
print(list(map(lambda x:x['name'],filter(lambda x:x['department']=='IT' and x['active']==True,employees))))
# Out:
# ['Rahul', 'Kiran']

# %% [markdown]
# SECTION 4 :
# REDUCE FUNCTION

# %% [markdown]
# Question 1
# numbers = [10, 20, 30, 40, 50]
# Using reduce(), calculate the sum of all numbers.

# %%
from functools import reduce
numbers = [10, 20, 30, 40, 50]
sum=reduce(lambda x,y:x+y,numbers)
print(sum)
# Out:
# 150

# %% [markdown]
# Question 2
# numbers = [2, 3, 4, 5]
# Using reduce(), calculate the product of all numbers.

# %%
numbers = [2, 3, 4, 5]
print(reduce(lambda x,y:x*y,numbers))
# Out:
# 120

# %% [markdown]
# Question 3
# numbers = [45, 12, 89, 34, 67, 91, 28]
# Using reduce(), find the maximum number.

# %%
numbers = [45, 12, 89, 34, 67, 91, 28]
print(reduce(lambda x,y:x if x>y else y,numbers))
# Out:
# 91

# %% [markdown]
# Question 4
# numbers = [45, 12, 89, 34, 67, 91, 28]
# Using reduce(), find the minimum number.

# %%
numbers = [45, 12, 89, 34, 67, 91, 28]
print(reduce(lambda x,y:x if x<y else y,numbers))
# Out:
# 12

# %% [markdown]
# Question 5
# words = ["Python", " ", "is", " ", "powerful"]
# Using reduce(), combine all strings into one sentence.

# %%
words = ["Python", " ", "is", " ", "powerful"]
print(reduce(lambda x,y:x+y,words))
# Out:
# Python is powerful

# %% [markdown]
# Question 6
# words = ["Python", "Azure", "Cloud", "AI"]
# Using reduce(), calculate the total number of characters in all words.

# %%
words = ["Python", "Azure", "Cloud", "AI"]
print(reduce(lambda x,y:x+len(y),words,0))
# Out:
# 18

# %% [markdown]
# Question 7
# number = 6
# numbers = list(range(1, number + 1))
# Using reduce(), calculate the factorial of number.

# %%
number = 6
numbers = list(range(1, number + 1))
print(reduce(lambda x,y:x*y,numbers))
# Out:
# 720

# %% [markdown]
# Question 8
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# Using reduce(), calculate the sum of only the even numbers. Do not create a separate filtered list.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
print(reduce(lambda x,y:x+y if y%2==0 else x,numbers,0))
# Out:
# 280

# %% [markdown]
# Question 9
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# Using reduce(), calculate the sum of only the odd numbers. Do not create a separate filtered list.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
print(reduce(lambda x,y:x+y if y%2!=0 else x,numbers,0))
# Out:
# 315

# %% [markdown]
# Question 10
# words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
# Using reduce(), find the longest word.

# %%
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
print(reduce(lambda x,y:x if len(x)>len(y) else y,words,''))
# Out:
# Kubernetes

# %% [markdown]
# Question 11
# words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
# Using reduce(), find the shortest word.

# %%
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
print(reduce(lambda x,y:x if len(x)<len(y) else y,words))


# from functools import reduce

# words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]

# result = reduce(lambda x, y: x if len(x) < len(y) else y, words)

# print(result)
# Out:
# AI

# %% [markdown]
# Question 12
# salaries = [45000, 65000, 72000, 82000, 55000]
# Using reduce(), calculate the total salary.

# %%
salaries = [45000, 65000, 72000, 82000, 55000]
print(reduce(lambda x,y:x+y,salaries))
# Out:
# 319000

# %% [markdown]
# Question 13
# employees = [
#     {"name": "Rahul", "salary": 45000},
#     {"name": "Anil", "salary": 65000},
#     {"name": "Sneha", "salary": 72000},
#     {"name": "Kiran", "salary": 82000},
#     {"name": "Meena", "salary": 55000}
# ]
# Using reduce(), calculate the total payroll directly from the dictionaries.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
print(reduce(lambda x,y:x+y['salary'],employees,0))
# Out:
# 319000

# %% [markdown]
# Question 14
# employees = [
#     {"name": "Rahul", "salary": 45000},
#     {"name": "Anil", "salary": 65000},
#     {"name": "Sneha", "salary": 72000},
#     {"name": "Kiran", "salary": 82000},
#     {"name": "Meena", "salary": 55000}
# ]
# Using reduce(), find the employee with the highest salary.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
print(reduce(lambda x,y:y['salary'] if y['salary']>x else x,employees,0))
# Out:
# 82000

# %% [markdown]
# Question 15
# students = [
#     {"name": "Ravi", "marks": 92},
#     {"name": "Kiran", "marks": 68},
#     {"name": "Meena", "marks": 85},
#     {"name": "Ajay", "marks": 48},
#     {"name": "Rahul", "marks": 95}
# ]
# Using reduce(), find the student with the highest marks.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Rahul", "marks": 95}
]
print(reduce(lambda x,y:y['marks'] if y['marks']>x else x,students,0))
# Out:
# 95

# %% [markdown]
# Question 16
# products = [
#     {"name": "Laptop", "price": 55000, "stock": 5},
#     {"name": "Mouse", "price": 600, "stock": 25},
#     {"name": "Keyboard", "price": 1500, "stock": 15},
#     {"name": "Monitor", "price": 18000, "stock": 8}
# ]
# Using reduce(), calculate the total stock quantity.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]
print(reduce(lambda x,y:x+y['stock'],products,0))
# Out:
# 53

# %% [markdown]
# Question 17
# products = [
#     {"name": "Laptop", "price": 55000, "stock": 5},
#     {"name": "Mouse", "price": 600, "stock": 25},
#     {"name": "Keyboard", "price": 1500, "stock": 15},
#     {"name": "Monitor", "price": 18000, "stock": 8}
# ]
# Using reduce(), calculate the total inventory value using price × stock.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]
print(reduce(lambda x,y:x+y['price']*y['stock'],products,0))
# Out:
# 456500

# %% [markdown]
# Question 18
# sales = [12000, 25000, 18000, 45000, 30000, 52000]
# Using reduce(), calculate the total sales amount.

# %%
sales = [12000, 25000, 18000, 45000, 30000, 52000]
print(reduce(lambda x,y:x+y,sales,0))
# Out:
# 182000

# %% [markdown]
# Question 19
# dictionaries = [
#     {"name": "Rahul"},
#     {"age": 30},
#     {"department": "IT"},
#     {"salary": 65000}
# ]
# Using reduce(), merge all dictionaries into one dictionary.

# %%
dictionaries = [
    {"name": "Rahul"},
    {"age": 30},
    {"department": "IT"},
    {"salary": 65000}
]
result=reduce(lambda x,y:(x.update(y),x)[1],dictionaries,{})
print(result)
# Out:
# {'name': 'Rahul', 'age': 30, 'department': 'IT', 'salary': 65000}

# %% [markdown]
# Question 20
# numbers = [12, 45, 12, 67, 45, 89, 23, 67, 100]
# Using reduce(), calculate the sum of unique numbers only. Do not directly use sum(set(numbers)).

# %%
numbers = [12, 45, 12, 67, 45, 89, 23, 67, 100]
result=reduce(lambda x,y : x+y if numbers.count(y)==1 else x,numbers,0)
print(result)
# from functools import reduce

# numbers = [12, 45, 12, 67, 45, 89, 23, 67, 100]

# result = reduce(lambda acc, num: (acc[0] | {num},acc[1] if num in acc[0] else acc[1] + num),numbers,(set(), 0))

# print(result[1])
# Out:
# 212

# %% [markdown]
# Section 5: Combined Lambda, map(), filter(), and reduce() — 20 Questions

# %% [markdown]
# Section 5: Combined Lambda, map(), filter(), and reduce() — 20 Questions
# Question 1
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# Using filter() and map():
#
# Extract all even numbers.
# Calculate the square of every even number.
# Return the squared values as a list.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
print(list(map(lambda x:x**2,filter(lambda x:x%2==0,numbers))))
# Out:
# [144, 3136, 1156, 6084, 10000]

# %% [markdown]
# Question 2
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# Using filter() and reduce():
#
# Extract all odd numbers.
# Calculate their total sum.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
print(reduce(lambda x,y:x+y,filter(lambda x:x%2 !=0,numbers),0))
# Out:
# 315

# %% [markdown]
# Question 3
# numbers = [10, 25, 40, 55, 70, 85, 100]
# Using filter() and map():
#
# Extract numbers greater than 50.
# Multiply every selected number by 2.

# %%
numbers = [10, 25, 40, 55, 70, 85, 100]
result=list(map(lambda x:x*2,filter(lambda x:x>50,numbers)))
print(result)
# Out:
# [110, 140, 170, 200]

# %% [markdown]
# Question 4
# numbers = [-15, 20, -35, 40, 50, -10, 60]
# Using filter(), map(), and reduce():
#
# Extract positive numbers.
# Calculate the square of every positive number.
# Calculate the total sum of the squared values.

# %%
numbers = [-15, 20, -35, 40, 50, -10, 60]
print(reduce(lambda x,y:x+y,map(lambda x:x**2,filter(lambda x:x>0,numbers))))
# Out:
# 8100

# %% [markdown]
# Question 5
# words = ["python", "azure", "ai", "developer", "cloud", "analytics", "spark"]
# Using filter() and map():
#
# Extract words containing more than five characters.
# Convert the selected words to uppercase.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics", "spark"]
len5=map(lambda x:x.upper(),filter(lambda x:len(x)>5,words))
print(list(len5))
# Out:
# ['PYTHON', 'DEVELOPER', 'ANALYTICS']

# %% [markdown]
# Question 6
# names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
# Using filter() and map():
#
# Extract names beginning with "A".
# Convert the selected names to lowercase.

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
result=map(lambda x:x.lower(),filter(lambda x:x.startswith('A'),names))
print(list(result))
# Out:
# ['anil', 'ajay', 'arjun', 'akhil']

# %% [markdown]
# Question 7
# numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
# Using filter() and reduce():
#
# Extract numbers divisible by both 3 and 5.
# Calculate their total sum.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
print(reduce(lambda x,y:x+y,filter(lambda x:x%3==0 and x%5==0,numbers),0))
# Out:
# 225

# %% [markdown]
# Question 8
# words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
# Using filter() and reduce():
#
# Extract palindrome words.
# Join them into one string separated by " | ".

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
print(reduce(lambda x,y:x+'|'+y,filter(lambda x:x[::-1]==x,words)))
# Out:
# madam|level|radar|civic

# %% [markdown]
# Question 9
# temperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42]
# Using filter(), map(), and reduce():
#
# Extract temperatures greater than 30°C.
# Convert the selected values into Fahrenheit.
# Calculate the average Fahrenheit temperature.
# Question 10
# prices = [450, 1200, 2500, 800, 5000, 1500, 7500]
# Using filter(), map(), and reduce():
#
# Extract prices greater than 1000.
# Apply a 10% discount to every selected price.
# Calculate the total discounted amount.

# %%
temperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42]
result=reduce(lambda x,y:x+y,map(lambda x:(9/5*x)+32,filter(lambda x:x>30,temperatures)))/len(list(filter(lambda x:x>30,temperatures)))
print(result)
# Out:
# 99.5

# %% [markdown]
# Question 10
# prices = [450, 1200, 2500, 800, 5000, 1500, 7500]
# Using filter(), map(), and reduce():
#
# Extract prices greater than 1000.
# Apply a 10% discount to every selected price.
# Calculate the total discounted amount.

# %%
prices = [450, 1200, 2500, 800, 5000, 1500, 7500]
discounted_Amount=map(lambda x:x-(x*10/100),filter(lambda x:x>1000,prices))
print(reduce(lambda x,y:x+y,discounted_Amount,0))
# Out:
# 15930.0

# %% [markdown]
# Question 11
# employees = [
#     {"id": 101, "name": "Rahul", "salary": 45000},
#     {"id": 102, "name": "Anil", "salary": 65000},
#     {"id": 103, "name": "Sneha", "salary": 72000},
#     {"id": 104, "name": "Kiran", "salary": 82000},
#     {"id": 105, "name": "Meena", "salary": 55000}
# ]
# Using filter() and map():
#
# Extract employees earning more than 60000.
# Increase their salary by 10%.
# Return their names and updated salaries.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000},
    {"id": 105, "name": "Meena", "salary": 55000}
]
salary=map(lambda x:{'id':x['id'],'name':x['name'],'salary':x['salary']+x['salary']*10/100},(filter(lambda x:x['salary']>60000,employees)))
print(list(salary))
# Out:
# [{'id': 102, 'name': 'Anil', 'salary': 71500.0}, {'id': 103, 'name': 'Sneha', 'salary': 79200.0}, {'id': 104, 'name': 'Kiran', 'salary': 90200.0}]

# %% [markdown]
# Question 12
# employees = [
#     {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000},
#     {"id": 102, "name": "Anil", "department": "HR", "salary": 65000},
#     {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000},
#     {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000},
#     {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000}
# ]
# Using filter() and reduce():
#
# Extract employees from the IT department.
# Calculate the total salary of IT employees.

# %%
employees = [
    {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000},
    {"id": 102, "name": "Anil", "department": "HR", "salary": 65000},
    {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000},
    {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000},
    {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000}
]
result=reduce(lambda x,y:x+y['salary'],filter(lambda x:x['department']=='IT',employees),0)
print(result)
# Out:
# 199000

# %% [markdown]
# Question 13
# employees = [
#     {"id": 101, "name": "Rahul", "salary": 45000, "active": True},
#     {"id": 102, "name": "Anil", "salary": 65000, "active": True},
#     {"id": 103, "name": "Sneha", "salary": 72000, "active": False},
#     {"id": 104, "name": "Kiran", "salary": 82000, "active": True},
#     {"id": 105, "name": "Meena", "salary": 55000, "active": True},
#     {"id": 106, "name": "Arjun", "salary": 98000, "active": False}
# ]
# Using filter(), map(), and reduce():
#
# Extract active employees.
# Increase every active employee's salary by 15%.
# Calculate the total updated payroll.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000, "active": True},
    {"id": 102, "name": "Anil", "salary": 65000, "active": True},
    {"id": 103, "name": "Sneha", "salary": 72000, "active": False},
    {"id": 104, "name": "Kiran", "salary": 82000, "active": True},
    {"id": 105, "name": "Meena", "salary": 55000, "active": True},
    {"id": 106, "name": "Arjun", "salary": 98000, "active": False}
]
result=map(lambda x:x['salary']+x['salary']*15/100,filter(lambda x:x['active']==True,employees))
print(reduce(lambda x,y:x+y,result,0))
# Out:
# 284050.0

# %% [markdown]
# Question 14
# students = [
#     {"name": "Ravi", "marks": 92, "passed": True},
#     {"name": "Kiran", "marks": 68, "passed": True},
#     {"name": "Meena", "marks": 85, "passed": True},
#     {"name": "Ajay", "marks": 48, "passed": True},
#     {"name": "Sneha", "marks": 35, "passed": False},
#     {"name": "Rahul", "marks": 95, "passed": True}
# ]
# Using filter() and reduce():
#
# Extract students who passed.
# Find the topper among the passed students.

# %%
students = [
    {"name": "Ravi", "marks": 92, "passed": True},
    {"name": "Kiran", "marks": 68, "passed": True},
    {"name": "Meena", "marks": 85, "passed": True},
    {"name": "Ajay", "marks": 48, "passed": True},
    {"name": "Sneha", "marks": 35, "passed": False},
    {"name": "Rahul", "marks": 95, "passed": True}
]
result=reduce(lambda x,y:y if y['marks']>x['marks'] else x,filter(lambda x:x['passed']==True,students))
print(result)
# Out:
# {'name': 'Rahul', 'marks': 95, 'passed': True}

# %% [markdown]
# Question 15
# students = [
#     {"name": "Ravi", "marks": 92},
#     {"name": "Kiran", "marks": 68},
#     {"name": "Meena", "marks": 85},
#     {"name": "Ajay", "marks": 48},
#     {"name": "Sneha", "marks": 79},
#     {"name": "Rahul", "marks": 95}
# ]
# Using filter(), map(), and reduce():
#
# Extract students scoring more than 70.
# Extract only their marks.
# Calculate the average marks.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79},
    {"name": "Rahul", "marks": 95}
]
result=map(lambda x:x['marks'],filter(lambda x:x['marks']>70,students))
ave=reduce(lambda x,y:x+y,result)/len(list(filter(lambda x:x['marks']>70,students)))
print(ave)
# Out:
# 87.75

# %% [markdown]
# Question 16
# products = [
#     {"name": "Laptop", "price": 55000, "stock": 5},
#     {"name": "Mouse", "price": 600, "stock": 25},
#     {"name": "Keyboard", "price": 1500, "stock": 0},
#     {"name": "Monitor", "price": 18000, "stock": 8},
#     {"name": "Printer", "price": 12000, "stock": 0},
#     {"name": "SSD", "price": 6500, "stock": 12}
# ]
# Using filter(), map(), and reduce():
#
# Extract products currently in stock.
# Calculate each product's inventory value using price × stock.
# Calculate the total inventory value.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0},
    {"name": "SSD", "price": 6500, "stock": 12}
]
result=list(map(lambda x:x['price']*x['stock'],filter(lambda x:x['stock']>0,products)))
print(list(result))
print(reduce(lambda x,y:x+y,result,0))
# Out:
# [275000, 15000, 144000, 78000]
# 512000

# %% [markdown]
# Question 17
# products = [
#     {"name": "Laptop", "price": 55000, "category": "Electronics"},
#     {"name": "Chair", "price": 4500, "category": "Furniture"},
#     {"name": "Monitor", "price": 18000, "category": "Electronics"},
#     {"name": "Desk", "price": 8500, "category": "Furniture"},
#     {"name": "SSD", "price": 6500, "category": "Electronics"}
# ]
# Using filter(), map(), and reduce():
#
# Extract products belonging to the Electronics category.
# Apply a 20% discount.
# Calculate the total discounted value.

# %%
products = [
    {"name": "Laptop", "price": 55000, "category": "Electronics"},
    {"name": "Chair", "price": 4500, "category": "Furniture"},
    {"name": "Monitor", "price": 18000, "category": "Electronics"},
    {"name": "Desk", "price": 8500, "category": "Furniture"},
    {"name": "SSD", "price": 6500, "category": "Electronics"}
]
result=list(map(lambda x:x['price']-x['price']*20/100,filter(lambda x:x['category']=='Electronics',products)))
print(list(result))
print(reduce(lambda x,y:x+y,result,0))
# Out:
# [44000.0, 14400.0, 5200.0]
# 63600.0

# %% [markdown]
# Question 17
# orders = [
#     {"order_id": 1001, "amount": 1200, "status": "Delivered"},
#     {"order_id": 1002, "amount": 3500, "status": "Pending"},
#     {"order_id": 1003, "amount": 8500, "status": "Delivered"},
#     {"order_id": 1004, "amount": 4200, "status": "Cancelled"},
#     {"order_id": 1005, "amount": 7600, "status": "Delivered"},
#     {"order_id": 1006, "amount": 5100, "status": "Pending"}
# ]
# Using filter() and reduce():
#
# Extract delivered orders.
# Calculate the total delivered revenue.

# %%
orders = [
    {"order_id": 1001, "amount": 1200, "status": "Delivered"},
    {"order_id": 1002, "amount": 3500, "status": "Pending"},
    {"order_id": 1003, "amount": 8500, "status": "Delivered"},
    {"order_id": 1004, "amount": 4200, "status": "Cancelled"},
    {"order_id": 1005, "amount": 7600, "status": "Delivered"},
    {"order_id": 1006, "amount": 5100, "status": "Pending"}
]
result=list(filter(lambda x:x['status']=='Delivered',orders))
print(result)
print(reduce(lambda x,y:x+y['amount'],result,0))
# Out:
# [{'order_id': 1001, 'amount': 1200, 'status': 'Delivered'}, {'order_id': 1003, 'amount': 8500, 'status': 'Delivered'}, {'order_id': 1005, 'amount': 7600, 'status': 'Delivered'}]
# 17300

# %% [markdown]
# Question 19
# transactions = [
#     {"id": 1, "amount": 1200},
#     {"id": 2, "amount": 5200},
#     {"id": 3, "amount": 18000},
#     {"id": 4, "amount": 2500},
#     {"id": 5, "amount": 9600},
#     {"id": 6, "amount": 7200}
# ]
# Using filter(), map(), and reduce():
#
# Extract transactions whose amount is greater than 5000.
# Add 18% GST to every selected transaction.
# Calculate the grand total after GST.

# %%
transactions = [
    {"id": 1, "amount": 1200},
    {"id": 2, "amount": 5200},
    {"id": 3, "amount": 18000},
    {"id": 4, "amount": 2500},
    {"id": 5, "amount": 9600},
    {"id": 6, "amount": 7200}
]
result=list(map(lambda x:{'id':x['id'],'amount':x['amount']+x['amount']*18/100},filter(lambda x:x['amount']>5000,transactions)))
print(result)
print(reduce(lambda x,y:x+y['amount'],result,0))
# Out:
# [{'id': 2, 'amount': 6136.0}, {'id': 3, 'amount': 21240.0}, {'id': 5, 'amount': 11328.0}, {'id': 6, 'amount': 8496.0}]
# 47200.0

# %% [markdown]
# Question 20
# sales_records = [
#     {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True},
#     {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True},
#     {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False},
#     {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True},
#     {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True},
#     {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True}
# ]
# Using filter(), map(), and reduce():
#
# Extract active salespeople from the South region.
# Calculate a 5% incentive for each selected salesperson.
# Create a list containing salesperson name, sales amount, and incentive.
# Calculate the total incentive payable.

# %%
sales_records = [
    {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True},
    {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True},
    {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False},
    {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True},
    {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True},
    {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True}
]
result=list(map(lambda x:{'salesperson':x['salesperson'],'sales':x['sales'],'intensive':x['sales']*5/100},filter(lambda x:x['region']=='South',sales_records)))
print(result)
print('incentive payable : ',reduce(lambda x,y:x+y['intensive'],result,0))
# Out:
# [{'salesperson': 'Rahul', 'sales': 45000, 'intensive': 2250.0}, {'salesperson': 'Sneha', 'sales': 72000, 'intensive': 3600.0}, {'salesperson': 'Kiran', 'sales': 82000, 'intensive': 4100.0}, {'salesperson': 'Arjun', 'sales': 98000, 'intensive': 4900.0}]
# incentive payable :  14850.0
